# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from enum import Enum
import os

# %% [markdown]
# #### Read all the json file from the igdb api

# %%
def load_files_to_df(keyword):
    dfs = []
    for filename in os.listdir("."):
        if keyword in filename: 
            dfs.append(pd.read_json(f'{filename}'))
    print(f"{len(dfs)} files loaded with the keyword {keyword}")
    df = pd.concat(dfs)
    df.reset_index(inplace=True)
    return df

# %%
games = load_files_to_df("file")
games = games.drop("created_at", axis=1).drop("external_games", axis=1).drop("release_dates", axis=1).drop("similar_games", axis=1).drop("updated_at", axis=1).drop("websites", axis=1).drop("parent_game", axis=1).drop("videos", axis=1).drop("game_engines", axis=1).drop("alternative_names", axis=1).drop("storyline", axis=1).drop("summary", axis=1)
games.info()
# Out:
# 310 files loaded with the keyword file
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154871 entries, 0 to 154870
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   index                    154871 non-null  int64
#  1   id                       154871 non-null  int64
#  2   artworks                 32600 non-null   object
#  3   category                 154871 non-null  int64
#  4   cover                    107683 non-null  float64
#  5   first_release_date       90517 non-null   float64
#  6   game_modes               79993 non-null   object
#  7   genres                   115282 non-null  object
#  8   name                     154871 non-null  object
#  9   platforms                93402 non-null   object
#  10  screenshots              91638 non-null   object
#  11  slug                     154871 non-null  object
#  12  status                   10174 non-null   float64
# ...

# %% [markdown]
# #### Categories and Game Modes

# %% [markdown]
# Remove games that aren't main games, like addons, expansions, bundles, ..., then replace the integer values with string representation

# %%
games = games[games["category"] == 0]

# %%
games
# Out:
#         index      id artworks  category     cover  first_release_date  \
# 0           0   90269  [36870]         0  145906.0        1.523405e+09
# 1           1   40104      NaN         0       NaN        5.364576e+08
# 2           2   24037      NaN         0   78219.0        1.439510e+09
# 3           3   41825      NaN         1   86236.0        1.498781e+09
# 4           4   68841      NaN         0   97021.0        1.506989e+09
# ...       ...     ...      ...       ...       ...                 ...
# 154866    495  100029      NaN         0       NaN                 NaN
# 154867    496   96015      NaN         0       NaN                 NaN
# 154868    497   98839  [15440]         0       NaN        1.523923e+09
# 154869    498  141039      NaN         1  119996.0        1.500336e+09
# 154870    499  157158      NaN         0  159505.0                 NaN
#
#        game_modes       genres  \
# 0             [1]     [31, 32]
# 1             NaN          [5]
# ...

# %%
#game mode enum
class GameModes(Enum):
    SINGLEPLAYER = 1
    MULTIPLAYER = 2
    CO_OP = 3
    SPLIT_SCREEN = 4
    MMO = 5
    BATTLE_ROYALE = 5
